# %% [markdown]
# <a href="https://colab.research.google.com/github/nimraa9090/AI-projects/blob/main/dataininglab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c38c2d38-88ca-4cde-be00-4fbca5ef5e56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c38c2d38-88ca-4cde-be00-4fbca5ef5e56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'Groceries_dataset.csv', 'sample_data']

# %%
import pandas as pd
df = pd.read_csv("Groceries_dataset.csv")

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
x = df['itemDescription'].value_counts().sort_values(ascending=False)[:10]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=x.index, y=x.values)
# Out:
# <Axes: xlabel='itemDescription'>

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
transactions_counts = df.groupby(['Member_number', 'itemDescription']).size().unstack(fill_value=0)
transactions = transactions_counts.applymap(lambda x: 1 if x > 0 else 0)
# Out:
# /tmp/ipykernel_5693/2032625469.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   transactions = transactions_counts.applymap(lambda x: 1 if x > 0 else 0)

# %%
transactions.fillna(0)
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
basket = transactions.astype(bool)

# %%
frequent_itemset = apriori(basket, min_support=0.06, use_colnames=True)

# %%
frequent_itemset = apriori(basket, min_support=0.06, use_colnames=True)

# %%
rules = association_rules(frequent_itemset, metric='lift', min_threshold=1)

# %%
rules[(rules['confidence'] > 0.4) & (rules['lift'] > 1.54)]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %%
rules.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0        (whole milk)              (beef)            0.458184
# 1              (beef)        (whole milk)            0.119548
# 2      (bottled beer)  (other vegetables)            0.158799
# 3  (other vegetables)      (bottled beer)            0.376603
# 4      (bottled beer)        (rolls/buns)            0.158799
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.119548  0.064135    0.139978  1.170886               1.0
# 1            0.458184  0.064135    0.536481  1.170886               1.0
# 2            0.376603  0.068497    0.431341  1.145345               1.0
# 3            0.158799  0.068497    0.181880  1.145345               1.0
# 4            0.349666  0.063109    0.397415  1.136555               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.009360    1.023754       0.269364  0.124875   0.023203    0.338229
# ...
