# %% [markdown]
# <a href="https://colab.research.google.com/github/nimraa9090/AI-projects/blob/main/lab12cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# Load the model
model = YOLO("yolov8n-seg.pt")
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
# Run inference on test.jpg
results = model(" test.jpg", conf=0.35)
result = results[0]
# Out:
# image 1/1 /content/ test.jpg: 480x640 1 bear, 1375.8ms
# Speed: 12.4ms preprocess, 1375.8ms inference, 39.9ms postprocess per image at shape (1, 3, 480, 640)

# %%
names = result.names
for box in result.boxes:
    cls_id = int(box.cls[0])
    conf = float(box.conf[0])
    print(f"Detected: {names[cls_id]} | Confidence: {round(conf, 3)}")
# Out:
# Detected: bear | Confidence: 0.434

# %%
# Plot the results
annotated = result.plot()

plt.figure(figsize=(10, 6))
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.title("YOLOv8 Detection and Segmentation Output")
plt.axis("off")
plt.show()
